# %%
x = 0
N = 512
for i=1:N
    x += div(77777,i) + 77777%i
end
println(x)
# Out:
# 595645

# %%
k = 42
Int(floor(k/2) + k)
for i=1:36
    k = Int(floor(k/2)+k)
end
k
# Out:
# 90811045

# %%
x = 0
for i=1:10^6
    x += floor(sqrt(i))
    if x >= 5555555
        println(i)
        break
    end
end
# Out:
# 41205

# %%
w = "..."
# Out:
# "..."

# %%
p = zeros(100)
for i=1:499
    l = parse(Int,w[i:i+1])
    p[l+1] += 1
end
findall(isequal(maximum(p)),p)
p[49]
# Out:
# 12.0

# %%
l = 0
N = 100
for i=1:N,j=i:N,k=j:N
    if i^2 + j^2 == k^2 && i*j/2 <= 8192
        l += 1
    end
end
l
# Out:
# 52

# %%
k = z = [31,28,30,30,31,30,31,31,30,31,30,31]
u = [31,29,30,30,31,30,31,31,30,31,30,31]
y = 2019
m = 0
d = 1
x = 0
l = 0

while x < 666
    l = mod(l,7)

    if l == 4 && d == 13
        x += 1
        println(y,m,d)
    end

    if mod(y,4) == 0
        k = u    
    else
        k = z
    end

    d += 1
    l += 1

    if d > k[m+1]
        m = mod(m + 1,12)
        d = 1
        if m == 0
            y += 1
        end
    end
end
println(y,m,d)
# Out:
# 2019913
# 2020313
# 2020613
# 2021313
# 2021613
# 2022313
# 2022613
# 2023313
# 2023613
# 2024813
# 20241113
# 2025813
# 20251113
# 2026813
# 20261113
# 2027813
# 20271113
# 2028213
# 2028513
# 2029113
# 2029213
# 2029513
# 2030113
# 2030213
# 2030513
# 2031113
# 2031213
# 2031513
# 2032113
# 20321013
# 20331013
# 20341013
# 20351013
# 2036713
# 2037713
# 2038713
# 2039713
# 2040413
# 2041013
# 2041413
# 2042013
# 2042413
# 2043013
# 2043413
# 2044013
# 2044913
# 2045913
# 2046913
# 2047913
# 2048313
# 2048613
# 2049313
# 2049613
# 2050313
# 2050613
# 2051313
# 2051613
# 2052813
# 20521113
# 2053813
# 20531113
# 2054813
# 20541113
# 2055813
# 20551113
# 2056213
# 2056513
# 2057113
# 2057213
# 2057513
# 2058113
# 2058213
# 2058513
# 2059113
# 2059213
# 2059513
# 2060113
# 20601013
# 20611013
# 20621013
# 20631013
# 2064713
# 2065713
# 2066713
# 2067713
# 2068413
# 2069013
# 2069413
# 2070013
# 2070413
# 2071013
# 2071413
# 2072013
# 2072913
# 2073913
# 2074913
# 2075913
# 2076313
# ...

# %%
k = u
# Out:
# 12-element Vector{Int64}:
#  31
#  29
#  30
#  30
#  31
#  30
#  31
#  31
#  30
#  31
#  30
#  31
